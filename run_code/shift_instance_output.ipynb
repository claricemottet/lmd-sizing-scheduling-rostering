# %%
from glob import glob
from os import path
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
from matplotlib.legend_handler import HandlerTuple
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pandas as pd
import os
import numpy as np
import re
import time
from datetime import datetime

# from solver import Instance

from argparse import Namespace
import sys
sys.path.append('../solver')
from solver_shifts import run_solver_shift_return
# Out:
# /home/clarice/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# ## Copied and Pasted from Alberto's readme
#
#
# The solver is a single Python script, contained in `solver/solver.py`.
# It takes the following parameters:
# * `-m` to specify the model name (`base`, `fixed`, `partflex`, or `flex`).
# * `-i` to specify the location of the instance file.
# * `-c` to specify the outsourcing cost multiplier (parameter OC in the paper).
# * `-r` to specify the regional bound multiplier (parameter RM in the paper).
# * `-g` to specify the global bound multiplier (parameter GM in the paper).
# * `-u` to specify the maximum number of shift start times for the `partflex` model (parameter $\mu$ in the paper).
# * `-o` to specify the location of the JSON solution file produced by the solver.

# %%
#Code that creates JSON file that outputs optimal shifts from scheduling solution

# for file in ['lyon_db=0.50_dt=uniform.json']:
for file in os.listdir(r'../instances'):
    if file not in os.listdir(r'../shifts'):
        shift_out = f"../shifts/{file}"
        dict_out = {
            'instance_file':[],
            'city':[],
            'demand_baseline':[],
            'demand_type':[],
            'model':[],
            'max_n_shifts':[],
            'outsourcing_cost_multiplier':[],
            'regional_multiplier':[],
            'global_multiplier':[],
            'run_time':[],
            'obj_val': [], 
            'status': [], 
            'gap': [],
            'region':[],
            'shifts_start':[],
            'shifts_end':[]
        }

        city_pattern = r'(\w+)_db'
        db_pattern = r'db=(\d+\.\d+)'
        dt_pattern = r'dt=(\w+)'

        city_match = re.search(city_pattern, file)
        db_match = re.search(db_pattern, file)
        dt_match = re.search(dt_pattern, file)
        
        city = city_match.group(1) if city_match else None
        demand_baseline = float(db_match.group(1)) if db_match else None
        demand_type = dt_match.group(1) if dt_match else None

        instance_ = f"../instances/{file}"

        start_time = time.time()
        datetime_format = datetime.fromtimestamp(start_time)
        print(f'file: {file}, start_time: {datetime_format}')

        for OC in [1.2, 1.5, 1.8, 2.0, 2.5]:
            for RM in [0.75, 1.00, 1.50, 1.80, 2.00]:
                for GM in [0.6, 0.7, 0.8, 0.9, 1.0]:
                    for model in ['fixed','flex','partflex']:
                        if model == 'partflex':
                            for max_n_shift in range(2,5):
                                dict_shifts, n_regions, dict_raw = run_solver_shift_return(model=model, instance=instance_, outsourcing_cost_multiplier=OC, regional_multiplier=RM, global_multiplier=GM, max_n_shifts=max_n_shift)
                                # if max_n_shift == 2:
                                #     dict_raw_out = dict_raw.copy()
                                dict_base = {
                                    'instance_file':[file]*n_regions,
                                    'city':[city]*n_regions,
                                    'demand_baseline':[demand_baseline]*n_regions,
                                    'demand_type':[demand_type]*n_regions,
                                    'model':[model]*n_regions,
                                    'max_n_shifts':[max_n_shift]*n_regions,
                                    'outsourcing_cost_multiplier':[OC]*n_regions,
                                    'regional_multiplier':[RM]*n_regions,
                                    'global_multiplier':[GM]*n_regions,
                                    'run_time': [dict_raw['run_time'][0]]*n_regions,
                                    'obj_val': [dict_raw['obj_val'][0]]*n_regions,
                                    'status': [dict_raw['status'][0]]*n_regions,
                                    'gap': [dict_raw['gap'][0]]*n_regions,
                                    'region':[region for region in range(0,n_regions)]
                                }
                                list_shift_start = []
                                list_shift_end = []
                                for region in range(0, n_regions):
                                    if region in dict_shifts.keys():
                                        list_shift_start.append(dict_shifts[region]['shifts_start'])
                                        list_shift_end.append(dict_shifts[region]['shifts_end'])
                                    else:
                                        list_shift_start.append({})
                                        list_shift_end.append({})
                                dict_base['shifts_start'] = list_shift_start
                                dict_base['shifts_end'] = list_shift_end
                                for key in dict_base.keys():
                                    dict_out[key].extend(dict_base[key])
                        else:
                            dict_shifts, n_regions, dict_raw = run_solver_shift_return(model=model, instance=instance_, outsourcing_cost_multiplier=OC, regional_multiplier=RM, global_multiplier=GM)
                            dict_base = {
                                'instance_file':[file]*n_regions,
                                'city':[city]*n_regions,
                                'demand_baseline':[demand_baseline]*n_regions,
                                'demand_type':[demand_type]*n_regions,
                                'model':[model]*n_regions,
                                'max_n_shifts':[np.nan]*n_regions,
                                'outsourcing_cost_multiplier':[OC]*n_regions,
                                'regional_multiplier':[RM]*n_regions,
                                'global_multiplier':[GM]*n_regions,
                                'run_time': [dict_raw['run_time'][0]]*n_regions,
                                'obj_val': [dict_raw['obj_val'][0]]*n_regions,
                                'status': [dict_raw['status'][0]]*n_regions,
                                'gap': [dict_raw['gap'][0]]*n_regions,
                                'region':[region for region in range(0,n_regions)]
                            }
                            list_shift_start = []
                            list_shift_end = []
                            for region in range(0, n_regions):
                                if region in dict_shifts.keys():
                                    list_shift_start.append(dict_shifts[region]['shifts_start'])
                                    list_shift_end.append(dict_shifts[region]['shifts_end'])
                                else:
                                    list_shift_start.append({})
                                    list_shift_end.append({})
                            dict_base['shifts_start'] = list_shift_start
                            dict_base['shifts_end'] = list_shift_end
                            for key in dict_base.keys():
                                dict_out[key].extend(dict_base[key])

        with open(shift_out, 'w') as f:
            json.dump(dict_out, f, indent=2)
# Out:
# file: berlin_db=1.00_dt=atend.json, start_time: 2024-09-19 18:42:21.995531
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-05-06
# file: paris_db=2.00_dt=doublepeak.json, start_time: 2024-09-19 18:48:51.338024
# file: paris_db=4.00_dt=atend.json, start_time: 2024-09-19 18:50:51.404100
# file: lyon_db=2.00_dt=peak.json, start_time: 2024-09-19 18:52:51.841776
# file: frankfurt_db=0.50_dt=atend.json, start_time: 2024-09-19 18:54:29.724610
# file: frankfurt_db=1.00_dt=uniform.json, start_time: 2024-09-19 18:57:46.263572
# file: lyon_db=0.50_dt=atend.json, start_time: 2024-09-19 19:00:53.687730
# file: frankfurt_db=0.50_dt=peak.json, start_time: 2024-09-19 19:02:28.623763
# file: paris_db=1.00_dt=uniform.json, start_time: 2024-09-19 19:05:39.634580
# file: lyon_db=1.00_dt=peak.json, start_time: 2024-09-19 19:07:40.588769
# file: paris_db=4.00_dt=doublepeak.json, start_time: 2024-09-19 19:09:16.163177
# file: paris_db=0.50_dt=doublepeak.json, start_time: 2024-09-19 19:11:16.223749
# file: paris_db=2.00_dt=uniform.json, start_time: 2024-09-19 19:13:16.461399
# file: berlin_db=2.00_dt=peak.json, start_time: 2024-09-19 19:15:15.225518
# file: berlin_db=1.00_dt=uniform.json, start_time: 2024-09-19 19:21:55.836076
# file: frankfurt_db=1.00_dt=peak.json, start_time: 2024-09-19 19:28:17.371742
# file: lyon_db=1.00_dt=uniform.json, start_time: 2024-09-19 19:31:32.800271
# file: frankfurt_db=4.00_dt=peak.json, start_time: 2024-09-19 19:33:04.716051
# file: paris_db=1.00_dt=peak.json, start_time: 2024-09-19 19:36:22.095538
# file: lyon_db=0.50_dt=peak.json, start_time: 2024-09-19 19:38:26.520460
# file: berlin_db=0.50_dt=atend.json, start_time: 2024-09-19 19:40:00.806333
# file: berlin_db=1.00_dt=peak.json, start_time: 2024-09-19 19:46:33.642092
# file: paris_db=1.00_dt=doublepeak.json, start_time: 2024-09-19 19:53:05.501591
# file: paris_db=4.00_dt=peak.json, start_time: 2024-09-19 19:55:03.246435
# file: frankfurt_db=4.00_dt=uniform.json, start_time: 2024-09-19 19:57:06.902497
# file: paris_db=1.00_dt=atend.json, start_time: 2024-09-19 20:00:14.726730
# file: frankfurt_db=2.00_dt=uniform.json, start_time: 2024-09-19 20:02:16.887710
# file: paris_db=0.50_dt=peak.json, start_time: 2024-09-19 20:05:26.172621
# file: frankfurt_db=2.00_dt=atend.json, start_time: 2024-09-19 20:07:27.921322
# file: berlin_db=0.50_dt=doublepeak.json, start_time: 2024-09-19 20:10:37.516623
# file: frankfurt_db=0.50_dt=doublepeak.json, start_time: 2024-09-19 20:17:02.201563
# file: paris_db=2.00_dt=atend.json, start_time: 2024-09-19 20:20:15.043532
# file: lyon_db=2.00_dt=atend.json, start_time: 2024-09-19 20:22:15.900884
# file: lyon_db=4.00_dt=peak.json, start_time: 2024-09-19 20:23:51.095510
# file: lyon_db=4.00_dt=doublepeak.json, start_time: 2024-09-19 20:25:31.873975
# file: frankfurt_db=1.00_dt=doublepeak.json, start_time: 2024-09-19 20:27:09.903591
# file: frankfurt_db=2.00_dt=peak.json, start_time: 2024-09-19 20:30:25.423325
# file: lyon_db=1.00_dt=doublepeak.json, start_time: 2024-09-19 20:33:42.006287
# file: lyon_db=4.00_dt=uniform.json, start_time: 2024-09-19 20:35:15.152555
# file: frankfurt_db=1.00_dt=atend.json, start_time: 2024-09-19 20:36:47.787657
# file: berlin_db=0.50_dt=uniform.json, start_time: 2024-09-19 20:39:59.396917
# file: berlin_db=4.00_dt=atend.json, start_time: 2024-09-19 20:46:12.110234
# file: lyon_db=1.00_dt=atend.json, start_time: 2024-09-19 20:52:48.795967
# file: lyon_db=2.00_dt=uniform.json, start_time: 2024-09-19 20:54:24.581698
# file: lyon_db=0.50_dt=doublepeak.json, start_time: 2024-09-19 20:56:00.141207
# file: frankfurt_db=4.00_dt=atend.json, start_time: 2024-09-19 20:57:33.946880
# file: paris_db=4.00_dt=uniform.json, start_time: 2024-09-19 21:00:44.996845
# file: frankfurt_db=4.00_dt=doublepeak.json, start_time: 2024-09-19 21:02:42.491369
# file: lyon_db=4.00_dt=atend.json, start_time: 2024-09-19 21:05:57.183918
# file: berlin_db=2.00_dt=atend.json, start_time: 2024-09-19 21:07:32.586545
# file: berlin_db=4.00_dt=peak.json, start_time: 2024-09-19 21:14:00.413475
# file: berlin_db=4.00_dt=doublepeak.json, start_time: 2024-09-19 21:20:41.243954
# file: berlin_db=2.00_dt=doublepeak.json, start_time: 2024-09-19 21:27:19.625024
# file: berlin_db=4.00_dt=uniform.json, start_time: 2024-09-19 21:33:46.597577
# file: berlin_db=2.00_dt=uniform.json, start_time: 2024-09-19 21:39:59.925282
# file: paris_db=0.50_dt=uniform.json, start_time: 2024-09-19 21:46:15.792689
# file: berlin_db=0.50_dt=peak.json, start_time: 2024-09-19 21:48:14.852829
# file: frankfurt_db=2.00_dt=doublepeak.json, start_time: 2024-09-19 21:54:36.242546
# file: berlin_db=1.00_dt=doublepeak.json, start_time: 2024-09-19 21:57:53.560021
# file: paris_db=2.00_dt=peak.json, start_time: 2024-09-19 22:04:16.785603
# file: frankfurt_db=0.50_dt=uniform.json, start_time: 2024-09-19 22:06:18.573543
# file: paris_db=0.50_dt=atend.json, start_time: 2024-09-19 22:09:25.473534
# file: lyon_db=2.00_dt=doublepeak.json, start_time: 2024-09-19 22:11:22.383296

# %%
#this is an example output of the shift creation code

list_output = []

for filename in os.listdir(r'../shifts'):
    if filename.find('json')>-1:
        with open(f'../shifts/{filename}', 'r') as file:
            data = json.load(file)
            df_ = pd.DataFrame(data)
            list_output.append(df_)

df_output = pd.concat(list_output, ignore_index = True)
df_output.to_excel(r'../run_code/df_shifts_example.xlsx', index = False)

# %%
df_output.head()
# Out:
#                   instance_file    city  demand_baseline demand_type  model  \
# 0  berlin_db=1.00_dt=atend.json  berlin              1.0       atend  fixed
# 1  berlin_db=1.00_dt=atend.json  berlin              1.0       atend  fixed
# 2  berlin_db=1.00_dt=atend.json  berlin              1.0       atend  fixed
# 3  berlin_db=1.00_dt=atend.json  berlin              1.0       atend  fixed
# 4  berlin_db=1.00_dt=atend.json  berlin              1.0       atend   flex
#
#    max_n_shifts  outsourcing_cost_multiplier  regional_multiplier  \
# 0           NaN                          1.2                 0.75
# 1           NaN                          1.2                 0.75
# 2           NaN                          1.2                 0.75
# 3           NaN                          1.2                 0.75
# 4           NaN                          1.2                 0.75
#
#    global_multiplier  run_time     obj_val  status  gap  region  \
# 0                0.6  0.055294  864.660023       2  0.0       0
# 1                0.6  0.055294  864.660023       2  0.0       1
# 2                0.6  0.055294  864.660023       2  0.0       2
# 3                0.6  0.055294  864.660023       2  0.0       3
# 4                0.6  0.070733  864.620024       2  0.0       0
#
#                shifts_start                shifts_end
# 0          {'0': 0, '1': 4}          {'0': 4, '1': 8}
# 1          {'0': 0, '1': 4}          {'0': 4, '1': 8}
# 2          {'0': 0, '1': 4}          {'0': 4, '1': 8}
# 3          {'0': 0, '1': 4}          {'0': 4, '1': 8}
# 4  {'0': 0, '1': 3, '2': 4}  {'0': 4, '1': 7, '2': 8}

# %%
df_freq = df_output.copy()
df_freq.drop_duplicates(subset = ['shifts_start'], inplace = True)
df_freq
# Out:
#                           instance_file       city  demand_baseline  \
# 0          berlin_db=1.00_dt=atend.json     berlin              1.0
# 4          berlin_db=1.00_dt=atend.json     berlin              1.0
# 39         berlin_db=1.00_dt=atend.json     berlin              1.0
# 87         berlin_db=1.00_dt=atend.json     berlin              1.0
# 286        berlin_db=1.00_dt=atend.json     berlin              1.0
# 387        berlin_db=1.00_dt=atend.json     berlin              1.0
# 987        berlin_db=1.00_dt=atend.json     berlin              1.0
# 2664   paris_db=2.00_dt=doublepeak.json      paris              2.0
# 2987   paris_db=2.00_dt=doublepeak.json      paris              2.0
# 3486   paris_db=2.00_dt=doublepeak.json      paris              2.0
# 7768          lyon_db=2.00_dt=peak.json       lyon              2.0
# 7892          lyon_db=2.00_dt=peak.json       lyon              2.0
# 7999          lyon_db=2.00_dt=peak.json       lyon              2.0
# 10004   frankfurt_db=0.50_dt=atend.json  frankfurt              0.5
# 12506      lyon_db=0.50_dt=uniform.json       lyon              0.5
# 12765      lyon_db=0.50_dt=uniform.json       lyon              0.5
# 17506        lyon_db=0.50_dt=atend.json       lyon              0.5
# 20004    frankfurt_db=0.50_dt=peak.json  frankfurt              0.5
# 20186    frankfurt_db=0.50_dt=peak.json  frankfurt              0.5
# 20705    frankfurt_db=0.50_dt=peak.json  frankfurt              0.5
# 20707    frankfurt_db=0.50_dt=peak.json  frankfurt              0.5
# 21965    frankfurt_db=0.50_dt=peak.json  frankfurt              0.5
# 21966    frankfurt_db=0.50_dt=peak.json  frankfurt              0.5
# 23266     paris_db=1.00_dt=uniform.json      paris              1.0
# 35488       berlin_db=2.00_dt=peak.json     berlin              2.0
# 53485      berlin_db=0.50_dt=atend.json     berlin              0.5
# 53551      berlin_db=0.50_dt=atend.json     berlin              0.5
#
#       demand_type     model  max_n_shifts  outsourcing_cost_multiplier  \
# 0           atend     fixed           NaN                          1.2
# 4           atend      flex           NaN                          1.2
# 39          atend  partflex           4.0                          1.2
# 87          atend      flex           NaN                          1.2
# 286         atend      flex           NaN                          1.2
# 387         atend      flex           NaN                          1.2
# 987         atend      flex           NaN                          1.5
# 2664   doublepeak      flex           NaN                          1.2
# 2987   doublepeak      flex           NaN                          1.2
# 3486   doublepeak      flex           NaN                          1.5
# 7768         peak  partflex           2.0                          1.2
# 7892         peak  partflex           3.0                          1.2
# 7999         peak  partflex           4.0                          1.2
# 10004       atend      flex           NaN                          1.2
# 12506     uniform      flex           NaN                          1.2
# 12765     uniform      flex           NaN                          1.2
# 17506       atend      flex           NaN                          1.2
# 20004        peak      flex           NaN                          1.2
# 20186        peak      flex           NaN                          1.2
# 20705        peak      flex           NaN                          1.5
# 20707        peak      flex           NaN                          1.5
# 21965        peak      flex           NaN                          2.0
# 21966        peak      flex           NaN                          2.0
# 23266     uniform      flex           NaN                          1.5
# 35488        peak  partflex           2.0                          1.2
# 53485       atend      flex           NaN                          1.5
# 53551       atend  partflex           2.0                          1.8
#
#        regional_multiplier  global_multiplier  run_time      obj_val  status  \
# 0                     0.75                0.6  0.055294   864.660023       2
# 4                     0.75                0.6  0.070733   864.620024       2
# 39                    0.75                0.7  0.070070   833.360021       2
# 87                    0.75                1.0  0.061848   750.800020       2
# 286                   1.50                1.0  0.062571   526.666686       2
# 387                   1.80                1.0  0.057956   495.466680       2
# 987                   2.00                1.0  0.060298   517.525013       2
# 2664                  1.00                0.9  0.015032  2700.064934       2
# 2987                  2.00                1.0  0.015372  1459.569414       2
# 3486                  2.00                1.0  0.019204  1491.286428       2
# 7768                  1.50                0.9  0.055794   976.299882       2
# 7892                  1.80                1.0  0.021263   672.569788       2
# 7999                  2.00                1.0  0.021280   606.658907       2
# 10004                 0.75                0.6  0.022454   264.900004       2
# 12506                 0.75                0.6  0.009173   357.100000       2
# 12765                 1.50                0.9  0.009887   189.596667       2
# 17506                 0.75                0.6  0.013143   405.514670       2
# 20004                 0.75                0.6  0.019519   261.673338       2
# 20186                 1.00                1.0  0.020965   218.693339       2
# 20705                 1.50                0.6  0.020002   260.866672       2
# 20707                 1.50                0.6  0.020002   260.866672       2
# 21965                 2.00                0.9  0.019031   219.888892       2
# 21966                 2.00                0.9  0.019031   219.888892       2
# 23266                 1.50                0.9  0.012916   702.798763       2
# 35488                 2.00                1.0  0.106157   871.578015       2
# 53485                 2.00                1.0  0.051359   354.975009       2
# 53551                 0.75                0.8  0.543870   614.410022       2
#
#        gap  region                              shifts_start  \
# 0      0.0       0                          {'0': 0, '1': 4}
# 4      0.0       0                  {'0': 0, '1': 3, '2': 4}
# 39     0.0       3                          {'0': 0, '1': 3}
# 87     0.0       3                          {'0': 3, '1': 4}
# 286    0.0       2          {'0': 0, '1': 2, '2': 3, '3': 4}
# 387    0.0       3                  {'0': 2, '1': 3, '2': 4}
# 987    0.0       3          {'0': 1, '1': 2, '2': 3, '3': 4}
# 2664   0.0       0                  {'0': 0, '1': 2, '2': 4}
# 2987   0.0       3  {'0': 0, '1': 1, '2': 2, '3': 3, '4': 4}
# 3486   0.0       2          {'0': 0, '1': 1, '2': 2, '3': 4}
# 7768   0.0       0                          {'0': 2, '1': 3}
# 7892   0.0       0                  {'0': 1, '1': 2, '2': 3}
# 7999   0.0       3          {'0': 0, '1': 1, '2': 2, '3': 3}
# 10004  0.0       0                                  {'0': 3}
# 12506  0.0       2                                        {}
# 12765  0.0       1                  {'0': 0, '1': 1, '2': 4}
# 17506  0.0       2                                  {'0': 0}
# 20004  0.0       0                                  {'0': 2}
# 20186  0.0       2                          {'0': 1, '1': 2}
# 20705  0.0       1                          {'0': 2, '1': 4}
# 20707  0.0       3                          {'0': 0, '1': 2}
# 21965  0.0       1                  {'0': 0, '1': 2, '2': 3}
# 21966  0.0       2                  {'0': 1, '1': 2, '2': 4}
# 23266  0.0       2          {'0': 0, '1': 1, '2': 3, '3': 4}
# 35488  0.0       0                          {'0': 1, '1': 3}
# 53485  0.0       1                  {'0': 1, '1': 3, '2': 4}
# 53551  0.0       3                                  {'0': 4}
#
#                                      shifts_end
# 0                              {'0': 4, '1': 8}
# 4                      {'0': 4, '1': 7, '2': 8}
# 39                             {'0': 4, '1': 7}
# 87                             {'0': 7, '1': 8}
# 286            {'0': 4, '1': 6, '2': 7, '3': 8}
# 387                    {'0': 6, '1': 7, '2': 8}
# 987            {'0': 5, '1': 6, '2': 7, '3': 8}
# 2664                   {'0': 4, '1': 6, '2': 8}
# 2987   {'0': 4, '1': 5, '2': 6, '3': 7, '4': 8}
# 3486           {'0': 4, '1': 5, '2': 6, '3': 8}
# 7768                           {'0': 6, '1': 7}
# 7892                   {'0': 5, '1': 6, '2': 7}
# 7999           {'0': 4, '1': 5, '2': 6, '3': 7}
# 10004                                  {'0': 7}
# 12506                                        {}
# 12765                  {'0': 4, '1': 5, '2': 8}
# 17506                                  {'0': 4}
# 20004                                  {'0': 6}
# 20186                          {'0': 5, '1': 6}
# 20705                          {'0': 6, '1': 8}
# 20707                          {'0': 4, '1': 6}
# 21965                  {'0': 4, '1': 6, '2': 7}
# 21966                  {'0': 5, '1': 6, '2': 8}
# 23266          {'0': 4, '1': 5, '2': 7, '3': 8}
# 35488                          {'0': 5, '1': 7}
# 53485                  {'0': 5, '1': 7, '2': 8}
# 53551                                  {'0': 8}
