# %%
from glob import glob
from os import path
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
from matplotlib.legend_handler import HandlerTuple
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pandas as pd
import os
import numpy as np
import re

# from solver import Instance

from argparse import Namespace
import sys
sys.path.append('../solver')
from solver_shifts import run_solver_shift_return
# Out:
# /home/clarice/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# ## Copied and Pasted from Alberto's readme
#
#
# The solver is a single Python script, contained in `solver/solver.py`.
# It takes the following parameters:
# * `-m` to specify the model name (`base`, `fixed`, `partflex`, or `flex`).
# * `-i` to specify the location of the instance file.
# * `-c` to specify the outsourcing cost multiplier (parameter OC in the paper).
# * `-r` to specify the regional bound multiplier (parameter RM in the paper).
# * `-g` to specify the global bound multiplier (parameter GM in the paper).
# * `-u` to specify the maximum number of shift start times for the `partflex` model (parameter $\mu$ in the paper).
# * `-o` to specify the location of the JSON solution file produced by the solver.

# %%
#Code that creates JSON file that outputs optimal shifts from scheduling solution

for file in os.listdir(r'../instances'):
    if (file.find('doublepeak') > -1) or (file.find('uniform') > -1):
        if file not in os.listdir(r'../shifts'):
            shift_out = f"../shifts/{file}"
            dict_out = {
                'instance_file':[],
                'city':[],
                'demand_baseline':[],
                'demand_type':[],
                'model':[],
                'max_n_shifts':[],
                'outsourcing_cost_multiplier':[],
                'regional_multiplier':[],
                'global_multiplier':[],
                'region':[],
                'shifts_start':[],
                'shifts_end':[]
            }

            city_pattern = r'(\w+)_db'
            db_pattern = r'db=(\d+\.\d+)'
            dt_pattern = r'dt=(\w+)'

            city_match = re.search(city_pattern, file)
            db_match = re.search(db_pattern, file)
            dt_match = re.search(dt_pattern, file)
            
            city = city_match.group(1) if city_match else None
            demand_baseline = float(db_match.group(1)) if db_match else None
            demand_type = dt_match.group(1) if dt_match else None

            instance_ = f"../instances/{file}"

            for OC in [1.2, 1.5, 1.8, 2.0, 2.5]:
                for RM in [1.5]:
                    for GM in [0.8]:
                        for model in ['fixed','flex','partflex']:
                            if model == 'partflex':
                                for max_n_shift in range(2,5):
                                    dict_shifts, n_regions, dict_raw = run_solver_shift_return(model=model, instance=instance_, outsourcing_cost_multiplier=OC, regional_multiplier=RM, global_multiplier=GM, max_n_shifts=max_n_shift)
                                    # if max_n_shift == 2:
                                    #     dict_raw_out = dict_raw.copy()
                                    dict_base = {
                                        'instance_file':[file]*n_regions,
                                        'city':[city]*n_regions,
                                        'demand_baseline':[demand_baseline]*n_regions,
                                        'demand_type':[demand_type]*n_regions,
                                        'model':[model]*n_regions,
                                        'max_n_shifts':[max_n_shift]*n_regions,
                                        'outsourcing_cost_multiplier':[OC]*n_regions,
                                        'regional_multiplier':[RM]*n_regions,
                                        'global_multiplier':[GM]*n_regions,
                                        'region':[region for region in range(0,n_regions)]
                                    }
                                    list_shift_start = []
                                    list_shift_end = []
                                    for region in range(0, n_regions):
                                        if region in dict_shifts.keys():
                                            list_shift_start.append(dict_shifts[region]['shifts_start'])
                                            list_shift_end.append(dict_shifts[region]['shifts_end'])
                                        else:
                                            list_shift_start.append({})
                                            list_shift_end.append({})
                                    dict_base['shifts_start'] = list_shift_start
                                    dict_base['shifts_end'] = list_shift_end
                                    for key in dict_base.keys():
                                        dict_out[key].extend(dict_base[key])
                            else:
                                dict_shifts, n_regions, dict_raw = run_solver_shift_return(model=model, instance=instance_, outsourcing_cost_multiplier=OC, regional_multiplier=RM, global_multiplier=GM)
                                dict_base = {
                                    'instance_file':[file]*n_regions,
                                    'city':[city]*n_regions,
                                    'demand_baseline':[demand_baseline]*n_regions,
                                    'demand_type':[demand_type]*n_regions,
                                    'model':[model]*n_regions,
                                    'max_n_shifts':[np.nan]*n_regions,
                                    'outsourcing_cost_multiplier':[OC]*n_regions,
                                    'regional_multiplier':[RM]*n_regions,
                                    'global_multiplier':[GM]*n_regions,
                                    'region':[region for region in range(0,n_regions)]
                                }
                                list_shift_start = []
                                list_shift_end = []
                                for region in range(0, n_regions):
                                    if region in dict_shifts.keys():
                                        list_shift_start.append(dict_shifts[region]['shifts_start'])
                                        list_shift_end.append(dict_shifts[region]['shifts_end'])
                                    else:
                                        list_shift_start.append({})
                                        list_shift_end.append({})
                                dict_base['shifts_start'] = list_shift_start
                                dict_base['shifts_end'] = list_shift_end
                                for key in dict_base.keys():
                                    dict_out[key].extend(dict_base[key])

            with open(shift_out, 'w') as f:
                json.dump(dict_out, f, indent=2)
# Out:
# in instance
# in solver
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-12
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14692 rows, 22728 columns and 42846 nonzeros
# Model fingerprint: 0x98693486
# Variable types: 14160 continuous, 8568 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 9e+01]
# Found heuristic solution: objective 2305.2800009
# Found heuristic solution: objective 2305.2799862
# Presolve removed 13751 rows and 14123 columns
# Presolve time: 0.03s
# Presolved: 941 rows, 8605 columns, 17105 nonzeros
# Found heuristic solution: objective 2305.2800000
# Variable types: 1462 continuous, 7143 integer (0 binary)
#
# Root relaxation: objective 8.089900e+02, 1017 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     808.9900170  808.99002  0.00%     -    0s
#
# Explored 1 nodes (1017 simplex iterations) in 0.10 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 808.99 2305.28
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.089900170000e+02, best bound 8.089900170000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14713 rows, 22733 columns and 43166 nonzeros
# Model fingerprint: 0x6e986178
# Variable types: 14160 continuous, 8573 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+01]
# Found heuristic solution: objective 2305.2800009
# Found heuristic solution: objective 2305.2799862
# Presolve removed 13755 rows and 14064 columns
# Presolve time: 0.04s
# Presolved: 958 rows, 8669 columns, 17426 nonzeros
# Found heuristic solution: objective 2305.2800000
# Variable types: 1462 continuous, 7207 integer (5 binary)
#
# Root relaxation: objective 8.089900e+02, 915 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     808.9900170  808.99002  0.00%     -    0s
#
# Explored 1 nodes (915 simplex iterations) in 0.08 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 808.99 2305.28
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.089900170000e+02, best bound 8.089900170000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14713 rows, 22733 columns and 43166 nonzeros
# Model fingerprint: 0x20acd64b
# Variable types: 14160 continuous, 8573 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+01]
# Found heuristic solution: objective 2305.2800009
# Found heuristic solution: objective 2305.2799862
# Presolve removed 13755 rows and 14064 columns
# Presolve time: 0.03s
# Presolved: 958 rows, 8669 columns, 17426 nonzeros
# Found heuristic solution: objective 2305.2800000
# Variable types: 1462 continuous, 7207 integer (5 binary)
#
# Root relaxation: objective 8.089900e+02, 915 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     808.9900170  808.99002  0.00%     -    0s
#
# Explored 1 nodes (915 simplex iterations) in 0.07 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 808.99 2305.28
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.089900170000e+02, best bound 8.089900170000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14713 rows, 22733 columns and 43166 nonzeros
# Model fingerprint: 0x277e96c3
# Variable types: 14160 continuous, 8573 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+01]
# Found heuristic solution: objective 2305.2800009
# Found heuristic solution: objective 2305.2799862
# Presolve removed 13755 rows and 14064 columns
# Presolve time: 0.03s
# Presolved: 958 rows, 8669 columns, 17426 nonzeros
# Found heuristic solution: objective 2305.2800000
# Variable types: 1462 continuous, 7207 integer (5 binary)
#
# Root relaxation: objective 8.089900e+02, 915 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     808.9900170  808.99002  0.00%     -    0s
#
# Explored 1 nodes (915 simplex iterations) in 0.09 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 808.99 2305.28
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.089900170000e+02, best bound 8.089900170000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14692 rows, 22728 columns and 42846 nonzeros
# Model fingerprint: 0xeb79070d
# Variable types: 14160 continuous, 8568 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 1e+02]
# Found heuristic solution: objective 2881.6000000
# Presolve removed 13751 rows and 14123 columns
# Presolve time: 0.04s
# Presolved: 941 rows, 8605 columns, 17105 nonzeros
# Variable types: 1462 continuous, 7143 integer (0 binary)
#
# Root relaxation: objective 8.400125e+02, 943 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     840.0125210  840.01252  0.00%     -    0s
#
# Explored 1 nodes (943 simplex iterations) in 0.07 seconds (0.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 840.013 2881.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.400125210000e+02, best bound 8.400125210000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14713 rows, 22733 columns and 43166 nonzeros
# Model fingerprint: 0xf414bf66
# Variable types: 14160 continuous, 8573 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+02]
# Found heuristic solution: objective 2881.6000000
# Presolve removed 13755 rows and 14064 columns
# Presolve time: 0.03s
# Presolved: 958 rows, 8669 columns, 17426 nonzeros
# Variable types: 1462 continuous, 7207 integer (5 binary)
#
# Root relaxation: objective 8.400125e+02, 954 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     840.0125210  840.01252  0.00%     -    0s
#
# Explored 1 nodes (954 simplex iterations) in 0.06 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 840.013 2881.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.400125210000e+02, best bound 8.400125210000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14713 rows, 22733 columns and 43166 nonzeros
# Model fingerprint: 0x7fefa7ce
# Variable types: 14160 continuous, 8573 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+02]
# Found heuristic solution: objective 2881.6000000
# Presolve removed 13755 rows and 14064 columns
# Presolve time: 0.03s
# Presolved: 958 rows, 8669 columns, 17426 nonzeros
# Variable types: 1462 continuous, 7207 integer (5 binary)
#
# Root relaxation: objective 8.400125e+02, 954 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     840.0125210  840.01252  0.00%     -    0s
#
# Explored 1 nodes (954 simplex iterations) in 0.11 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 840.013 2881.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.400125210000e+02, best bound 8.400125210000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14713 rows, 22733 columns and 43166 nonzeros
# Model fingerprint: 0x234a8ddf
# Variable types: 14160 continuous, 8573 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+02]
# Found heuristic solution: objective 2881.6000000
# Presolve removed 13755 rows and 14064 columns
# Presolve time: 0.05s
# Presolved: 958 rows, 8669 columns, 17426 nonzeros
# Variable types: 1462 continuous, 7207 integer (5 binary)
#
# Root relaxation: objective 8.400125e+02, 954 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     840.0125210  840.01252  0.00%     -    0s
#
# Explored 1 nodes (954 simplex iterations) in 0.09 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 840.013 2881.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.400125210000e+02, best bound 8.400125210000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14692 rows, 22728 columns and 42846 nonzeros
# Model fingerprint: 0xc7de1209
# Variable types: 14160 continuous, 8568 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 1e+02]
# Found heuristic solution: objective 3457.9199991
# Found heuristic solution: objective 3457.9199853
# Presolve removed 13751 rows and 14123 columns
# Presolve time: 0.03s
# Presolved: 941 rows, 8605 columns, 17105 nonzeros
# Found heuristic solution: objective 3457.9200000
# Variable types: 1462 continuous, 7143 integer (0 binary)
#
# Root relaxation: objective 8.704150e+02, 995 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     870.4150210  870.41502  0.00%     -    0s
#
# Explored 1 nodes (995 simplex iterations) in 0.07 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 870.415 3457.92
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.704150210000e+02, best bound 8.704150210000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14713 rows, 22733 columns and 43166 nonzeros
# Model fingerprint: 0x82d735b5
# Variable types: 14160 continuous, 8573 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+02]
# Found heuristic solution: objective 3457.9199991
# Found heuristic solution: objective 3457.9199853
# Presolve removed 13755 rows and 14064 columns
# Presolve time: 0.03s
# Presolved: 958 rows, 8669 columns, 17426 nonzeros
# Found heuristic solution: objective 3457.9200000
# Variable types: 1462 continuous, 7207 integer (5 binary)
#
# Root relaxation: objective 8.704150e+02, 912 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     870.4150210  870.41502  0.00%     -    0s
#
# Explored 1 nodes (912 simplex iterations) in 0.07 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 870.415 3457.92
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.704150210000e+02, best bound 8.704150210000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14713 rows, 22733 columns and 43166 nonzeros
# Model fingerprint: 0x2899965a
# Variable types: 14160 continuous, 8573 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+02]
# Found heuristic solution: objective 3457.9199991
# Found heuristic solution: objective 3457.9199853
# Presolve removed 13755 rows and 14064 columns
# Presolve time: 0.03s
# Presolved: 958 rows, 8669 columns, 17426 nonzeros
# Found heuristic solution: objective 3457.9200000
# Variable types: 1462 continuous, 7207 integer (5 binary)
#
# Root relaxation: objective 8.704150e+02, 912 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     870.4150210  870.41502  0.00%     -    0s
#
# Explored 1 nodes (912 simplex iterations) in 0.07 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 870.415 3457.92
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.704150210000e+02, best bound 8.704150210000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14713 rows, 22733 columns and 43166 nonzeros
# Model fingerprint: 0x27a97b72
# Variable types: 14160 continuous, 8573 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+02]
# Found heuristic solution: objective 3457.9199991
# Found heuristic solution: objective 3457.9199853
# Presolve removed 13755 rows and 14064 columns
# Presolve time: 0.03s
# Presolved: 958 rows, 8669 columns, 17426 nonzeros
# Found heuristic solution: objective 3457.9200000
# Variable types: 1462 continuous, 7207 integer (5 binary)
#
# Root relaxation: objective 8.704150e+02, 912 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     870.4150210  870.41502  0.00%     -    0s
#
# Explored 1 nodes (912 simplex iterations) in 0.07 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 870.415 3457.92
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.704150210000e+02, best bound 8.704150210000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14692 rows, 22728 columns and 42846 nonzeros
# Model fingerprint: 0xc14c70da
# Variable types: 14160 continuous, 8568 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 2e+02]
# Found heuristic solution: objective 3842.1333333
# Presolve removed 13751 rows and 14123 columns
# Presolve time: 0.03s
# Presolved: 941 rows, 8605 columns, 17105 nonzeros
# Variable types: 1462 continuous, 7143 integer (0 binary)
#
# Root relaxation: objective 8.906834e+02, 949 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     890.6833543  890.68335  0.00%     -    0s
#
# Explored 1 nodes (949 simplex iterations) in 0.06 seconds (0.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 890.683 3842.13
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.906833543333e+02, best bound 8.906833543333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14713 rows, 22733 columns and 43166 nonzeros
# Model fingerprint: 0xa9b1e542
# Variable types: 14160 continuous, 8573 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# Found heuristic solution: objective 3842.1333333
# Presolve removed 13755 rows and 14064 columns
# Presolve time: 0.03s
# Presolved: 958 rows, 8669 columns, 17426 nonzeros
# Variable types: 1462 continuous, 7207 integer (5 binary)
#
# Root relaxation: objective 8.906834e+02, 937 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     890.6833543  890.68335  0.00%     -    0s
#
# Explored 1 nodes (937 simplex iterations) in 0.06 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 890.683 3842.13
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.906833543333e+02, best bound 8.906833543333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14713 rows, 22733 columns and 43166 nonzeros
# Model fingerprint: 0x1be27da6
# Variable types: 14160 continuous, 8573 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# Found heuristic solution: objective 3842.1333333
# Presolve removed 13755 rows and 14064 columns
# Presolve time: 0.03s
# Presolved: 958 rows, 8669 columns, 17426 nonzeros
# Variable types: 1462 continuous, 7207 integer (5 binary)
#
# Root relaxation: objective 8.906834e+02, 910 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     890.6833543  890.68335  0.00%     -    0s
#
# Explored 1 nodes (910 simplex iterations) in 0.06 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 890.683 3842.13
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.906833543333e+02, best bound 8.906833543333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14713 rows, 22733 columns and 43166 nonzeros
# Model fingerprint: 0xf1f77f30
# Variable types: 14160 continuous, 8573 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# Found heuristic solution: objective 3842.1333333
# Presolve removed 13755 rows and 14064 columns
# Presolve time: 0.03s
# Presolved: 958 rows, 8669 columns, 17426 nonzeros
# Variable types: 1462 continuous, 7207 integer (5 binary)
#
# Root relaxation: objective 8.906834e+02, 910 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     890.6833543  890.68335  0.00%     -    0s
#
# Explored 1 nodes (910 simplex iterations) in 0.06 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 890.683 3842.13
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.906833543333e+02, best bound 8.906833543333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14692 rows, 22728 columns and 42846 nonzeros
# Model fingerprint: 0x48d7c218
# Variable types: 14160 continuous, 8568 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 2e+02]
# Found heuristic solution: objective 4802.6666667
# Presolve removed 13751 rows and 14123 columns
# Presolve time: 0.03s
# Presolved: 941 rows, 8605 columns, 17105 nonzeros
# Variable types: 1462 continuous, 7143 integer (0 binary)
#
# Root relaxation: objective 9.413542e+02, 909 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     941.3541877  941.35419  0.00%     -    0s
#
# Explored 1 nodes (909 simplex iterations) in 0.06 seconds (0.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 941.354 4802.67
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.413541876667e+02, best bound 9.413541876667e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14713 rows, 22733 columns and 43166 nonzeros
# Model fingerprint: 0x53876a7b
# Variable types: 14160 continuous, 8573 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# Found heuristic solution: objective 4802.6666667
# Presolve removed 13755 rows and 14064 columns
# Presolve time: 0.03s
# Presolved: 958 rows, 8669 columns, 17426 nonzeros
# Variable types: 1462 continuous, 7207 integer (5 binary)
#
# Root relaxation: objective 9.413542e+02, 930 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     941.3541877  941.35419  0.00%     -    0s
#
# Explored 1 nodes (930 simplex iterations) in 0.06 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 941.354 4802.67
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.413541876667e+02, best bound 9.413541876667e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14713 rows, 22733 columns and 43166 nonzeros
# Model fingerprint: 0x9d76e3aa
# Variable types: 14160 continuous, 8573 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# Found heuristic solution: objective 4802.6666667
# Presolve removed 13755 rows and 14064 columns
# Presolve time: 0.03s
# Presolved: 958 rows, 8669 columns, 17426 nonzeros
# Variable types: 1462 continuous, 7207 integer (5 binary)
#
# Root relaxation: objective 9.413542e+02, 930 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     941.3541877  941.35419  0.00%     -    0s
#
# Explored 1 nodes (930 simplex iterations) in 0.06 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 941.354 4802.67
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.413541876667e+02, best bound 9.413541876667e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14713 rows, 22733 columns and 43166 nonzeros
# Model fingerprint: 0xc05752b6
# Variable types: 14160 continuous, 8573 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# Found heuristic solution: objective 4802.6666667
# Presolve removed 13755 rows and 14064 columns
# Presolve time: 0.03s
# Presolved: 958 rows, 8669 columns, 17426 nonzeros
# Variable types: 1462 continuous, 7207 integer (5 binary)
#
# Root relaxation: objective 9.413542e+02, 930 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     941.3541877  941.35419  0.00%     -    0s
#
# Explored 1 nodes (930 simplex iterations) in 0.06 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 941.354 4802.67
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.413541876667e+02, best bound 9.413541876667e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 472
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5020 rows, 5936 columns and 10078 nonzeros
# Model fingerprint: 0x8620750d
# Variable types: 4800 continuous, 1136 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 3.200002e+11
# Presolve removed 4665 rows and 4525 columns
# Presolve time: 0.01s
# Presolved: 355 rows, 1411 columns, 2744 nonzeros
# Found heuristic solution: objective 1313.4400000
# Variable types: 524 continuous, 887 integer (13 binary)
#
# Root relaxation: objective 5.487647e+02, 476 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     548.7646877  548.76469  0.00%     -    0s
#
# Explored 1 nodes (476 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 548.765 1313.44 3.2e+11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.487646876667e+02, best bound 5.487646876667e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 160
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5041 rows, 5941 columns and 10203 nonzeros
# Model fingerprint: 0xac2c4732
# Variable types: 4800 continuous, 1141 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 3.200002e+11
# Presolve removed 4669 rows and 4505 columns
# Presolve time: 0.01s
# Presolved: 372 rows, 1436 columns, 2870 nonzeros
# Found heuristic solution: objective 1313.4400000
# Variable types: 524 continuous, 912 integer (18 binary)
#
# Root relaxation: objective 5.487647e+02, 497 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  548.76469    0    2 1313.44000  548.76469  58.2%     -    0s
# H    0     0                     758.6262115  548.76469  27.7%     -    0s
# H    0     0                     571.3626887  548.76469  3.96%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 2
#
# Explored 1 nodes (497 simplex iterations) in 0.04 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 571.363 758.626 1313.44 3.2e+11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.713626886667e+02, best bound 5.713626886667e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 160
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5041 rows, 5941 columns and 10203 nonzeros
# Model fingerprint: 0xf5bbd98a
# Variable types: 4800 continuous, 1141 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 3.200002e+11
# Presolve removed 4669 rows and 4505 columns
# Presolve time: 0.01s
# Presolved: 372 rows, 1436 columns, 2870 nonzeros
# Found heuristic solution: objective 1313.4400000
# Variable types: 524 continuous, 912 integer (18 binary)
#
# Root relaxation: objective 5.487647e+02, 497 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     548.7646877  548.76469  0.00%     -    0s
#
# Explored 1 nodes (497 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 548.765 1313.44 3.2e+11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.487646876667e+02, best bound 5.487646876667e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 160
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5041 rows, 5941 columns and 10203 nonzeros
# Model fingerprint: 0x162425bb
# Variable types: 4800 continuous, 1141 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 3.200002e+11
# Presolve removed 4669 rows and 4505 columns
# Presolve time: 0.01s
# Presolved: 372 rows, 1436 columns, 2870 nonzeros
# Found heuristic solution: objective 1313.4400000
# Variable types: 524 continuous, 912 integer (18 binary)
#
# Root relaxation: objective 5.487647e+02, 497 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     548.7646877  548.76469  0.00%     -    0s
#
# Explored 1 nodes (497 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 548.765 1313.44 3.2e+11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.487646876667e+02, best bound 5.487646876667e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 160
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5020 rows, 5936 columns and 10078 nonzeros
# Model fingerprint: 0x5fcbc088
# Variable types: 4800 continuous, 1136 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 6e+02]
# Found heuristic solution: objective 1641.8000000
# Presolve removed 4665 rows and 4525 columns
# Presolve time: 0.01s
# Presolved: 355 rows, 1411 columns, 2744 nonzeros
# Variable types: 524 continuous, 887 integer (13 binary)
#
# Root relaxation: objective 6.172884e+02, 473 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     617.2883533  617.28835  0.00%     -    0s
#
# Explored 1 nodes (473 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 617.288 1641.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.172883533333e+02, best bound 6.172883533333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 160
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5041 rows, 5941 columns and 10203 nonzeros
# Model fingerprint: 0xb10dd2e1
# Variable types: 4800 continuous, 1141 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 6e+02]
# Found heuristic solution: objective 1641.8000000
# Presolve removed 4669 rows and 4505 columns
# Presolve time: 0.01s
# Presolved: 372 rows, 1436 columns, 2870 nonzeros
# Variable types: 524 continuous, 912 integer (18 binary)
#
# Root relaxation: objective 6.172884e+02, 460 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  617.28835    0    2 1641.80000  617.28835  62.4%     -    0s
# H    0     0                     873.8856152  617.28835  29.4%     -    0s
# H    0     0                     634.2033553  617.28835  2.67%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 1
#
# Explored 1 nodes (460 simplex iterations) in 0.03 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 634.203 873.886 1641.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.342033553333e+02, best bound 6.342033553333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 160
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5041 rows, 5941 columns and 10203 nonzeros
# Model fingerprint: 0x9f4d20b0
# Variable types: 4800 continuous, 1141 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 6e+02]
# Found heuristic solution: objective 1641.8000000
# Presolve removed 4669 rows and 4505 columns
# Presolve time: 0.01s
# Presolved: 372 rows, 1436 columns, 2870 nonzeros
# Variable types: 524 continuous, 912 integer (18 binary)
#
# Root relaxation: objective 6.172884e+02, 459 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     617.2883533  617.28835  0.00%     -    0s
#
# Explored 1 nodes (459 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 617.288 1641.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.172883533333e+02, best bound 6.172883533333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 160
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5041 rows, 5941 columns and 10203 nonzeros
# Model fingerprint: 0x386d326e
# Variable types: 4800 continuous, 1141 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 6e+02]
# Found heuristic solution: objective 1641.8000000
# Presolve removed 4669 rows and 4505 columns
# Presolve time: 0.01s
# Presolved: 372 rows, 1436 columns, 2870 nonzeros
# Variable types: 524 continuous, 912 integer (18 binary)
#
# Root relaxation: objective 6.172884e+02, 459 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     617.2883533  617.28835  0.00%     -    0s
#
# Explored 1 nodes (459 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 617.288 1641.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.172883533333e+02, best bound 6.172883533333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 160
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5020 rows, 5936 columns and 10078 nonzeros
# Model fingerprint: 0x44075d5f
# Variable types: 4800 continuous, 1136 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 7e+02]
# Found heuristic solution: objective 3.200002e+11
# Presolve removed 4665 rows and 4525 columns
# Presolve time: 0.01s
# Presolved: 355 rows, 1411 columns, 2744 nonzeros
# Found heuristic solution: objective 1970.1600000
# Variable types: 524 continuous, 887 integer (13 binary)
#
# Root relaxation: objective 6.840560e+02, 456 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     684.0560210  684.05602  0.00%     -    0s
#
# Explored 1 nodes (456 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 684.056 1970.16 3.2e+11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.840560210000e+02, best bound 6.840560210000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 160
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# ...
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 8017 rows, 10357 columns and 14801 nonzeros
# Model fingerprint: 0x249e0bf3
# Variable types: 7680 continuous, 2677 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 3e+01]
# Found heuristic solution: objective 475.1399934
# Found heuristic solution: objective 475.1399914
# Presolve removed 7464 rows and 7663 columns
# Presolve time: 0.01s
# Presolved: 553 rows, 2694 columns, 5725 nonzeros
# Found heuristic solution: objective 475.1399999
# Variable types: 497 continuous, 2197 integer (19 binary)
#
# Root relaxation: objective 2.451200e+02, 411 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     245.1200030  245.12000  0.00%     -    0s
#
# Explored 1 nodes (411 simplex iterations) in 0.03 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 245.12 475.14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.451200030000e+02, best bound 2.451200030000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 256
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 8017 rows, 10357 columns and 14801 nonzeros
# Model fingerprint: 0x20385ec2
# Variable types: 7680 continuous, 2677 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 3e+01]
# Found heuristic solution: objective 475.1399934
# Found heuristic solution: objective 475.1399914
# Presolve removed 7464 rows and 7663 columns
# Presolve time: 0.01s
# Presolved: 553 rows, 2694 columns, 5725 nonzeros
# Found heuristic solution: objective 475.1399999
# Variable types: 497 continuous, 2197 integer (19 binary)
#
# Root relaxation: objective 2.451200e+02, 411 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     245.1200030  245.12000  0.00%     -    0s
#
# Explored 1 nodes (411 simplex iterations) in 0.03 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 245.12 475.14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.451200030000e+02, best bound 2.451200030000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 256
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 7996 rows, 10352 columns and 14616 nonzeros
# Model fingerprint: 0x973dbd0f
# Variable types: 7680 continuous, 2672 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 3e+01]
# Found heuristic solution: objective 527.9333333
# Presolve removed 7460 rows and 7695 columns
# Presolve time: 0.01s
# Presolved: 536 rows, 2657 columns, 5539 nonzeros
# Variable types: 497 continuous, 2160 integer (14 binary)
#
# Root relaxation: objective 2.528000e+02, 393 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     252.8000030  252.80000  0.00%     -    0s
#
# Explored 1 nodes (393 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 252.8 527.933
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.528000030000e+02, best bound 2.528000030000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 256
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 8017 rows, 10357 columns and 14801 nonzeros
# Model fingerprint: 0x2cc5db8e
# Variable types: 7680 continuous, 2677 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 3e+01]
# Found heuristic solution: objective 527.9333333
# Presolve removed 7464 rows and 7663 columns
# Presolve time: 0.01s
# Presolved: 553 rows, 2694 columns, 5725 nonzeros
# Variable types: 497 continuous, 2197 integer (19 binary)
#
# Root relaxation: objective 2.528000e+02, 423 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     252.8000030  252.80000  0.00%     -    0s
#
# Explored 1 nodes (423 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 252.8 527.933
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.528000030000e+02, best bound 2.528000030000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 256
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 8017 rows, 10357 columns and 14801 nonzeros
# Model fingerprint: 0x90092efa
# Variable types: 7680 continuous, 2677 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 3e+01]
# Found heuristic solution: objective 527.9333333
# Presolve removed 7464 rows and 7663 columns
# Presolve time: 0.01s
# Presolved: 553 rows, 2694 columns, 5725 nonzeros
# Variable types: 497 continuous, 2197 integer (19 binary)
#
# Root relaxation: objective 2.528000e+02, 430 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     252.8000030  252.80000  0.00%     -    0s
#
# Explored 1 nodes (430 simplex iterations) in 0.03 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 252.8 527.933
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.528000030000e+02, best bound 2.528000030000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 256
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 8017 rows, 10357 columns and 14801 nonzeros
# Model fingerprint: 0x3024bc78
# Variable types: 7680 continuous, 2677 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 3e+01]
# Found heuristic solution: objective 527.9333333
# Presolve removed 7464 rows and 7663 columns
# Presolve time: 0.01s
# Presolved: 553 rows, 2694 columns, 5725 nonzeros
# Variable types: 497 continuous, 2197 integer (19 binary)
#
# Root relaxation: objective 2.528000e+02, 430 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     252.8000030  252.80000  0.00%     -    0s
#
# Explored 1 nodes (430 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 252.8 527.933
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.528000030000e+02, best bound 2.528000030000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 256
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 7996 rows, 10352 columns and 14616 nonzeros
# Model fingerprint: 0x336d11a2
# Variable types: 7680 continuous, 2672 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 4e+01]
# Found heuristic solution: objective 659.9166667
# Presolve removed 7460 rows and 7695 columns
# Presolve time: 0.01s
# Presolved: 536 rows, 2657 columns, 5539 nonzeros
# Variable types: 497 continuous, 2160 integer (14 binary)
#
# Root relaxation: objective 2.720000e+02, 410 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     272.0000030  272.00000  0.00%     -    0s
#
# Explored 1 nodes (410 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 272 659.917
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000030000e+02, best bound 2.720000030000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 256
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 8017 rows, 10357 columns and 14801 nonzeros
# Model fingerprint: 0xdf139183
# Variable types: 7680 continuous, 2677 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 4e+01]
# Found heuristic solution: objective 659.9166667
# Presolve removed 7464 rows and 7663 columns
# Presolve time: 0.01s
# Presolved: 553 rows, 2694 columns, 5725 nonzeros
# Variable types: 497 continuous, 2197 integer (19 binary)
#
# Root relaxation: objective 2.720000e+02, 435 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     272.0000030  272.00000  0.00%     -    0s
#
# Explored 1 nodes (435 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 272 659.917
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000030000e+02, best bound 2.720000030000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 256
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 8017 rows, 10357 columns and 14801 nonzeros
# Model fingerprint: 0xc57713a5
# Variable types: 7680 continuous, 2677 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 4e+01]
# Found heuristic solution: objective 659.9166667
# Presolve removed 7464 rows and 7663 columns
# Presolve time: 0.03s
# Presolved: 553 rows, 2694 columns, 5725 nonzeros
# Variable types: 497 continuous, 2197 integer (19 binary)
#
# Root relaxation: objective 2.720000e+02, 434 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     272.0000030  272.00000  0.00%     -    0s
#
# Explored 1 nodes (434 simplex iterations) in 0.07 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 272 659.917
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000030000e+02, best bound 2.720000030000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 256
# in instance
# in solver
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 8017 rows, 10357 columns and 14801 nonzeros
# Model fingerprint: 0x6470e9f5
# Variable types: 7680 continuous, 2677 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 4e+01]
# Found heuristic solution: objective 659.9166667
# Presolve removed 7464 rows and 7663 columns
# Presolve time: 0.01s
# Presolved: 553 rows, 2694 columns, 5725 nonzeros
# Variable types: 497 continuous, 2197 integer (19 binary)
#
# Root relaxation: objective 2.720000e+02, 434 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     272.0000030  272.00000  0.00%     -    0s
#
# Explored 1 nodes (434 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 272 659.917
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000030000e+02, best bound 2.720000030000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 256

# %%
#this is an example output of the shift creation code

list_output = []

for filename in os.listdir(r'../shifts'):
    if filename.find('json')>-1:
        with open(f'../shifts/{filename}', 'r') as file:
            data = json.load(file)
            df_ = pd.DataFrame(data)
            list_output.append(df_)

df_output = pd.concat(list_output, ignore_index = True)
df_output.to_excel(r'../code_team/code_cm/df_shifts_example.xlsx', index = False)

# %%
df_output.head()
# Out:
#                       instance_file   city  demand_baseline demand_type  \
# 0  paris_db=2.00_dt=doublepeak.json  paris              2.0  doublepeak
# 1  paris_db=2.00_dt=doublepeak.json  paris              2.0  doublepeak
# 2  paris_db=2.00_dt=doublepeak.json  paris              2.0  doublepeak
# 3  paris_db=2.00_dt=doublepeak.json  paris              2.0  doublepeak
# 4  paris_db=2.00_dt=doublepeak.json  paris              2.0  doublepeak
#
#    model  max_n_shifts  outsourcing_cost_multiplier  regional_multiplier  \
# 0  fixed           NaN                          1.2                  1.5
# 1  fixed           NaN                          1.2                  1.5
# 2  fixed           NaN                          1.2                  1.5
# 3  fixed           NaN                          1.2                  1.5
# 4   flex           NaN                          1.2                  1.5
#
#    global_multiplier  region              shifts_start  \
# 0                0.8       0          {'0': 0, '1': 4}
# 1                0.8       1          {'0': 0, '1': 4}
# 2                0.8       2          {'0': 0, '1': 4}
# 3                0.8       3          {'0': 0, '1': 4}
# 4                0.8       0  {'0': 0, '1': 2, '2': 4}
#
#                  shifts_end
# 0          {'0': 4, '1': 8}
# 1          {'0': 4, '1': 8}
# 2          {'0': 4, '1': 8}
# 3          {'0': 4, '1': 8}
# 4  {'0': 4, '1': 6, '2': 8}

# %%
df_freq = df_output.copy()
df_freq.drop_duplicates(subset = ['shifts_start'], inplace = True)
df_freq
# Out:
#                              instance_file       city  demand_baseline  \
# 0         paris_db=2.00_dt=doublepeak.json      paris              2.0
# 4         paris_db=2.00_dt=doublepeak.json      paris              2.0
# 704         berlin_db=1.00_dt=uniform.json     berlin              1.0
# 707         berlin_db=1.00_dt=uniform.json     berlin              1.0
# 1204     berlin_db=0.50_dt=doublepeak.json     berlin              0.5
# 1305  frankfurt_db=0.50_dt=doublepeak.json  frankfurt              0.5
# 1344  frankfurt_db=0.50_dt=doublepeak.json  frankfurt              0.5
#
#      demand_type  model  max_n_shifts  outsourcing_cost_multiplier  \
# 0     doublepeak  fixed           NaN                          1.2
# 4     doublepeak   flex           NaN                          1.2
# 704      uniform   flex           NaN                          1.2
# 707      uniform   flex           NaN                          1.2
# 1204  doublepeak   flex           NaN                          1.2
# 1305  doublepeak   flex           NaN                          1.2
# 1344  doublepeak   flex           NaN                          1.8
#
#       regional_multiplier  global_multiplier  region  \
# 0                     1.5                0.8       0
# 4                     1.5                0.8       0
# 704                   1.5                0.8       0
# 707                   1.5                0.8       3
# 1204                  1.5                0.8       0
# 1305                  1.5                0.8       1
# 1344                  1.5                0.8       0
#
#                   shifts_start                shifts_end
# 0             {'0': 0, '1': 4}          {'0': 4, '1': 8}
# 4     {'0': 0, '1': 2, '2': 4}  {'0': 4, '1': 6, '2': 8}
# 704   {'0': 0, '1': 3, '2': 4}  {'0': 4, '1': 7, '2': 8}
# 707   {'0': 0, '1': 1, '2': 4}  {'0': 4, '1': 5, '2': 8}
# 1204                  {'0': 2}                  {'0': 6}
# 1305          {'0': 2, '1': 3}          {'0': 6, '1': 7}
# 1344          {'0': 2, '1': 4}          {'0': 6, '1': 8}
