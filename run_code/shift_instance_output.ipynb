# %%
from glob import glob
from os import path
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
from matplotlib.legend_handler import HandlerTuple
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pandas as pd
import os
import numpy as np
import re

# from solver import Instance

from argparse import Namespace
import sys
sys.path.append('../solver')
from solver_shifts import run_solver_shift_return
# Out:
# /home/clarice/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# ## Copied and Pasted from Alberto's readme
#
#
# The solver is a single Python script, contained in `solver/solver.py`.
# It takes the following parameters:
# * `-m` to specify the model name (`base`, `fixed`, `partflex`, or `flex`).
# * `-i` to specify the location of the instance file.
# * `-c` to specify the outsourcing cost multiplier (parameter OC in the paper).
# * `-r` to specify the regional bound multiplier (parameter RM in the paper).
# * `-g` to specify the global bound multiplier (parameter GM in the paper).
# * `-u` to specify the maximum number of shift start times for the `partflex` model (parameter $\mu$ in the paper).
# * `-o` to specify the location of the JSON solution file produced by the solver.

# %%
#Code that creates JSON file that outputs optimal shifts from scheduling solution

# for file in ['lyon_db=0.50_dt=uniform.json']:
for file in os.listdir(r'../instances'):
    if file not in os.listdir(r'../shifts'):
        shift_out = f"../shifts/{file}"
        dict_out = {
            'instance_file':[],
            'city':[],
            'demand_baseline':[],
            'demand_type':[],
            'model':[],
            'max_n_shifts':[],
            'outsourcing_cost_multiplier':[],
            'regional_multiplier':[],
            'global_multiplier':[],
            'run_time':[],
            'obj_val': [], 
            'status': [], 
            'gap': [],
            'region':[],
            'shifts_start':[],
            'shifts_end':[]
        }

        city_pattern = r'(\w+)_db'
        db_pattern = r'db=(\d+\.\d+)'
        dt_pattern = r'dt=(\w+)'

        city_match = re.search(city_pattern, file)
        db_match = re.search(db_pattern, file)
        dt_match = re.search(dt_pattern, file)
        
        city = city_match.group(1) if city_match else None
        demand_baseline = float(db_match.group(1)) if db_match else None
        demand_type = dt_match.group(1) if dt_match else None

        instance_ = f"../instances/{file}"

        for OC in [1.2, 1.5, 1.8, 2.0, 2.5]:
            for RM in [0.75, 1.00, 1.50, 1.80, 2.00]:
                for GM in [0.6, 0.7, 0.8, 0.9, 1.0]:
                    for model in ['fixed','flex','partflex']:
                        if model == 'partflex':
                            for max_n_shift in range(2,5):
                                dict_shifts, n_regions, dict_raw = run_solver_shift_return(model=model, instance=instance_, outsourcing_cost_multiplier=OC, regional_multiplier=RM, global_multiplier=GM, max_n_shifts=max_n_shift)
                                # if max_n_shift == 2:
                                #     dict_raw_out = dict_raw.copy()
                                dict_base = {
                                    'instance_file':[file]*n_regions,
                                    'city':[city]*n_regions,
                                    'demand_baseline':[demand_baseline]*n_regions,
                                    'demand_type':[demand_type]*n_regions,
                                    'model':[model]*n_regions,
                                    'max_n_shifts':[max_n_shift]*n_regions,
                                    'outsourcing_cost_multiplier':[OC]*n_regions,
                                    'regional_multiplier':[RM]*n_regions,
                                    'global_multiplier':[GM]*n_regions,
                                    'run_time': [dict_raw['run_time'][0]]*n_regions,
                                    'obj_val': [dict_raw['obj_val'][0]]*n_regions,
                                    'status': [dict_raw['status'][0]]*n_regions,
                                    'gap': [dict_raw['gap'][0]]*n_regions,
                                    'region':[region for region in range(0,n_regions)]
                                }
                                list_shift_start = []
                                list_shift_end = []
                                for region in range(0, n_regions):
                                    if region in dict_shifts.keys():
                                        list_shift_start.append(dict_shifts[region]['shifts_start'])
                                        list_shift_end.append(dict_shifts[region]['shifts_end'])
                                    else:
                                        list_shift_start.append({})
                                        list_shift_end.append({})
                                dict_base['shifts_start'] = list_shift_start
                                dict_base['shifts_end'] = list_shift_end
                                for key in dict_base.keys():
                                    dict_out[key].extend(dict_base[key])
                        else:
                            dict_shifts, n_regions, dict_raw = run_solver_shift_return(model=model, instance=instance_, outsourcing_cost_multiplier=OC, regional_multiplier=RM, global_multiplier=GM)
                            dict_base = {
                                'instance_file':[file]*n_regions,
                                'city':[city]*n_regions,
                                'demand_baseline':[demand_baseline]*n_regions,
                                'demand_type':[demand_type]*n_regions,
                                'model':[model]*n_regions,
                                'max_n_shifts':[np.nan]*n_regions,
                                'outsourcing_cost_multiplier':[OC]*n_regions,
                                'regional_multiplier':[RM]*n_regions,
                                'global_multiplier':[GM]*n_regions,
                                'run_time': [dict_raw['run_time'][0]]*n_regions,
                                'obj_val': [dict_raw['obj_val'][0]]*n_regions,
                                'status': [dict_raw['status'][0]]*n_regions,
                                'gap': [dict_raw['gap'][0]]*n_regions,
                                'region':[region for region in range(0,n_regions)]
                            }
                            list_shift_start = []
                            list_shift_end = []
                            for region in range(0, n_regions):
                                if region in dict_shifts.keys():
                                    list_shift_start.append(dict_shifts[region]['shifts_start'])
                                    list_shift_end.append(dict_shifts[region]['shifts_end'])
                                else:
                                    list_shift_start.append({})
                                    list_shift_end.append({})
                            dict_base['shifts_start'] = list_shift_start
                            dict_base['shifts_end'] = list_shift_end
                            for key in dict_base.keys():
                                dict_out[key].extend(dict_base[key])

        with open(shift_out, 'w') as f:
            json.dump(dict_out, f, indent=2)
# Out:
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4000 rows, 4368 columns and 8356 nonzeros
# Model fingerprint: 0xf674535d
# Variable types: 3840 continuous, 528 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3856 rows and 3989 columns
# Presolve time: 0.01s
# Presolved: 144 rows, 379 columns, 849 nonzeros
# Found heuristic solution: objective 437.0066667
# Variable types: 165 continuous, 214 integer (0 binary)
#
# Root relaxation: objective 3.571000e+02, 86 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     357.1000000  357.10000  0.00%     -    0s
#
# Explored 1 nodes (86 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 357.1 437.007 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.571000000000e+02, best bound 3.571000000000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4028 rows, 4624 columns and 8712 nonzeros
# Model fingerprint: 0x7c270e6e
# Variable types: 3840 continuous, 784 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3732 rows and 3704 columns
# Presolve time: 0.01s
# Presolved: 296 rows, 920 columns, 1878 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 330 continuous, 590 integer (0 binary)
#
# Root relaxation: objective 3.571000e+02, 151 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     357.1000000  357.10000  0.00%     -    0s
#
# Explored 1 nodes (151 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 357.1 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.571000000000e+02, best bound 3.571000000000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0xe4015f12
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3736 rows and 3688 columns
# Presolve time: 0.01s
# Presolved: 313 rows, 941 columns, 1984 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 330 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 3.571000e+02, 155 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     357.1000000  357.10000  0.00%     -    0s
#
# Explored 1 nodes (155 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 357.1 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.571000000000e+02, best bound 3.571000000000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0x47d782cc
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3736 rows and 3688 columns
# Presolve time: 0.01s
# Presolved: 313 rows, 941 columns, 1984 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 330 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 3.571000e+02, 155 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     357.1000000  357.10000  0.00%     -    0s
#
# Explored 1 nodes (155 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 357.1 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.571000000000e+02, best bound 3.571000000000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0x00c4493c
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3736 rows and 3688 columns
# Presolve time: 0.01s
# Presolved: 313 rows, 941 columns, 1984 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 330 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 3.571000e+02, 155 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     357.1000000  357.10000  0.00%     -    0s
#
# Explored 1 nodes (155 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 357.1 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.571000000000e+02, best bound 3.571000000000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4000 rows, 4368 columns and 8356 nonzeros
# Model fingerprint: 0xde0f41f5
# Variable types: 3840 continuous, 528 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3856 rows and 3989 columns
# Presolve time: 0.01s
# Presolved: 144 rows, 379 columns, 849 nonzeros
# Found heuristic solution: objective 426.9000000
# Variable types: 165 continuous, 214 integer (0 binary)
#
# Root relaxation: objective 3.376533e+02, 99 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     337.6533363  337.65334  0.00%     -    0s
#
# Explored 1 nodes (99 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 337.653 426.9 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.376533363333e+02, best bound 3.376533363333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4028 rows, 4624 columns and 8712 nonzeros
# Model fingerprint: 0xa9ececa2
# Variable types: 3840 continuous, 784 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3732 rows and 3704 columns
# Presolve time: 0.01s
# Presolved: 296 rows, 920 columns, 1878 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 330 continuous, 590 integer (0 binary)
#
# Root relaxation: objective 3.376533e+02, 168 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     337.6533363  337.65334  0.00%     -    0s
#
# Explored 1 nodes (168 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 337.653 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.376533363333e+02, best bound 3.376533363333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0x7fd3a4f6
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3736 rows and 3688 columns
# Presolve time: 0.01s
# Presolved: 313 rows, 941 columns, 1984 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 330 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 3.376533e+02, 177 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     337.6533363  337.65334  0.00%     -    0s
#
# Explored 1 nodes (177 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 337.653 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.376533363333e+02, best bound 3.376533363333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0x8edafdd6
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3736 rows and 3688 columns
# Presolve time: 0.01s
# Presolved: 313 rows, 941 columns, 1984 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 330 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 3.376533e+02, 177 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     337.6533363  337.65334  0.00%     -    0s
#
# Explored 1 nodes (177 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 337.653 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.376533363333e+02, best bound 3.376533363333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0x429c7dfd
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3736 rows and 3688 columns
# Presolve time: 0.01s
# Presolved: 313 rows, 941 columns, 1984 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 330 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 3.376533e+02, 177 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     337.6533363  337.65334  0.00%     -    0s
#
# Explored 1 nodes (177 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 337.653 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.376533363333e+02, best bound 3.376533363333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4000 rows, 4368 columns and 8356 nonzeros
# Model fingerprint: 0xc3b4addc
# Variable types: 3840 continuous, 528 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3856 rows and 3989 columns
# Presolve time: 0.01s
# Presolved: 144 rows, 379 columns, 849 nonzeros
# Found heuristic solution: objective 418.3800000
# Variable types: 165 continuous, 214 integer (0 binary)
#
# Root relaxation: objective 3.205733e+02, 91 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     320.5733353  320.57334  0.00%     -    0s
#
# Explored 1 nodes (91 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 320.573 418.38 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.205733353333e+02, best bound 3.205733353333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4028 rows, 4624 columns and 8712 nonzeros
# Model fingerprint: 0x30f32bd8
# Variable types: 3840 continuous, 784 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3732 rows and 3704 columns
# Presolve time: 0.01s
# Presolved: 296 rows, 920 columns, 1878 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 330 continuous, 590 integer (0 binary)
#
# Root relaxation: objective 3.205733e+02, 193 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     320.5733353  320.57334  0.00%     -    0s
#
# Explored 1 nodes (193 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 320.573 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.205733353333e+02, best bound 3.205733353333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0xed0f19ea
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3736 rows and 3688 columns
# Presolve time: 0.01s
# Presolved: 313 rows, 941 columns, 1984 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 330 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 3.205733e+02, 203 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     320.5733353  320.57334  0.00%     -    0s
#
# Explored 1 nodes (203 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 320.573 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.205733353333e+02, best bound 3.205733353333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0x22bc9605
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3736 rows and 3688 columns
# Presolve time: 0.01s
# Presolved: 313 rows, 941 columns, 1984 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 330 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 3.205733e+02, 202 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     320.5733353  320.57334  0.00%     -    0s
#
# Explored 1 nodes (202 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 320.573 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.205733353333e+02, best bound 3.205733353333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0xd73bdd8e
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3736 rows and 3688 columns
# Presolve time: 0.01s
# Presolved: 313 rows, 941 columns, 1984 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 330 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 3.205733e+02, 202 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     320.5733353  320.57334  0.00%     -    0s
#
# Explored 1 nodes (202 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 320.573 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.205733353333e+02, best bound 3.205733353333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4000 rows, 4368 columns and 8356 nonzeros
# Model fingerprint: 0x03e3365b
# Variable types: 3840 continuous, 528 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3856 rows and 3989 columns
# Presolve time: 0.01s
# Presolved: 144 rows, 379 columns, 849 nonzeros
# Found heuristic solution: objective 410.1800030
# Variable types: 165 continuous, 214 integer (0 binary)
#
# Root relaxation: objective 3.044533e+02, 123 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     304.4533383  304.45334  0.00%     -    0s
#
# Explored 1 nodes (123 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 304.453 410.18 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.044533383333e+02, best bound 3.044533383333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4028 rows, 4624 columns and 8712 nonzeros
# Model fingerprint: 0x54f8c33e
# Variable types: 3840 continuous, 784 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3732 rows and 3704 columns
# Presolve time: 0.01s
# Presolved: 296 rows, 920 columns, 1878 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 330 continuous, 590 integer (0 binary)
#
# Root relaxation: objective 3.044533e+02, 233 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     304.4533383  304.45334  0.00%     -    0s
#
# Explored 1 nodes (233 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 304.453 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.044533383333e+02, best bound 3.044533383333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0xce3e0bea
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3736 rows and 3688 columns
# Presolve time: 0.01s
# Presolved: 313 rows, 941 columns, 1984 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 330 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 3.044533e+02, 252 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     304.4533383  304.45334  0.00%     -    0s
#
# Explored 1 nodes (252 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 304.453 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.044533383333e+02, best bound 3.044533383333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0x356c9a28
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3736 rows and 3688 columns
# Presolve time: 0.01s
# Presolved: 313 rows, 941 columns, 1984 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 330 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 3.044533e+02, 260 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     304.4533383  304.45334  0.00%     -    0s
#
# Explored 1 nodes (260 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 304.453 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.044533383333e+02, best bound 3.044533383333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0x27048358
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3736 rows and 3688 columns
# Presolve time: 0.01s
# Presolved: 313 rows, 941 columns, 1984 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 330 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 3.044533e+02, 260 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     304.4533383  304.45334  0.00%     -    0s
#
# Explored 1 nodes (260 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 304.453 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.044533383333e+02, best bound 3.044533383333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4000 rows, 4368 columns and 8356 nonzeros
# Model fingerprint: 0xc02b8c7b
# Variable types: 3840 continuous, 528 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3958 rows and 4237 columns
# Presolve time: 0.01s
# Presolved: 42 rows, 131 columns, 271 nonzeros
# Found heuristic solution: objective 300.4733393
# Variable types: 51 continuous, 80 integer (0 binary)
#
# Root relaxation: objective 2.746533e+02, 27 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     274.6533413  274.65334  0.00%     -    0s
#
# Explored 1 nodes (27 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 274.653 300.473 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.746533413333e+02, best bound 2.746533413333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4028 rows, 4624 columns and 8712 nonzeros
# Model fingerprint: 0x568a26f5
# Variable types: 3840 continuous, 784 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3941 rows and 4307 columns
# Presolve time: 0.01s
# Presolved: 87 rows, 317 columns, 607 nonzeros
# Found heuristic solution: objective 324.9800040
# Variable types: 102 continuous, 215 integer (0 binary)
#
# Root relaxation: objective 2.746533e+02, 60 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     274.6533413  274.65334  0.00%     -    0s
#
# Explored 1 nodes (60 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 274.653 324.98 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.746533413333e+02, best bound 2.746533413333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0xe7bded8d
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3744 rows and 3688 columns
# Presolve time: 0.01s
# Presolved: 305 rows, 941 columns, 1855 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 330 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 2.746533e+02, 200 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     274.6533413  274.65334  0.00%     -    0s
#
# Explored 1 nodes (200 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 274.653 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.746533413333e+02, best bound 2.746533413333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0x1447c07c
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3744 rows and 3688 columns
# Presolve time: 0.01s
# Presolved: 305 rows, 941 columns, 1855 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 330 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 2.746533e+02, 200 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     274.6533413  274.65334  0.00%     -    0s
#
# Explored 1 nodes (200 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 274.653 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.746533413333e+02, best bound 2.746533413333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0xd1d2f15a
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3744 rows and 3688 columns
# Presolve time: 0.01s
# Presolved: 305 rows, 941 columns, 1855 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 330 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 2.746533e+02, 200 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     274.6533413  274.65334  0.00%     -    0s
#
# Explored 1 nodes (200 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 274.653 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.746533413333e+02, best bound 2.746533413333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4000 rows, 4368 columns and 8356 nonzeros
# Model fingerprint: 0xc8f943f3
# Variable types: 3840 continuous, 528 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3856 rows and 3974 columns
# Presolve time: 0.01s
# Presolved: 144 rows, 394 columns, 864 nonzeros
# Found heuristic solution: objective 409.6933353
# Variable types: 180 continuous, 214 integer (0 binary)
#
# Root relaxation: objective 3.040333e+02, 102 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     304.0333383  304.03334  0.00%     -    0s
#
# Explored 1 nodes (102 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 304.033 409.693 515.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.040333383333e+02, best bound 3.040333383333e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4028 rows, 4624 columns and 8712 nonzeros
# Model fingerprint: 0x0be7794c
# Variable types: 3840 continuous, 784 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 8e+01]
# Found heuristic solution: objective 515.8400007
# Found heuristic solution: objective 515.8399964
# Presolve removed 3732 rows and 3677 columns
# Presolve time: 0.01s
# Presolved: 296 rows, 947 columns, 1905 nonzeros
# Found heuristic solution: objective 515.8400000
# Variable types: 357 continuous, 590 integer (0 binary)
#
# Root relaxation: objective 3.040333e+02, 240 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     304.0333383  304.03334  0.00%     -    0s
#
# Explored 1 nodes (240 simplex iterations) in 0.02 seconds (0.01 work units)
# ...
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 209.313 638.896 1074.67
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.093125020000e+02, best bound 2.093125020000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4028 rows, 4624 columns and 8712 nonzeros
# Model fingerprint: 0xa9af01e3
# Variable types: 3840 continuous, 784 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 2e+02]
# Found heuristic solution: objective 1074.6666667
# Presolve removed 3732 rows and 3664 columns
# Presolve time: 0.01s
# Presolved: 296 rows, 960 columns, 1918 nonzeros
# Variable types: 370 continuous, 590 integer (0 binary)
#
# Root relaxation: objective 2.093125e+02, 178 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     209.3125020  209.31250  0.00%     -    0s
#
# Explored 1 nodes (178 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 209.313 1074.67
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.093125020000e+02, best bound 2.093125020000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0xe4c2c829
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# Found heuristic solution: objective 1074.6666667
# Presolve removed 3736 rows and 3648 columns
# Presolve time: 0.01s
# Presolved: 313 rows, 981 columns, 2024 nonzeros
# Variable types: 370 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 2.093125e+02, 196 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     209.3125020  209.31250  0.00%     -    0s
#
# Explored 1 nodes (196 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 209.313 1074.67
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.093125020000e+02, best bound 2.093125020000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0x1ce0211d
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# Found heuristic solution: objective 1074.6666667
# Presolve removed 3736 rows and 3648 columns
# Presolve time: 0.01s
# Presolved: 313 rows, 981 columns, 2024 nonzeros
# Variable types: 370 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 2.093125e+02, 196 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     209.3125020  209.31250  0.00%     -    0s
#
# Explored 1 nodes (196 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 209.313 1074.67
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.093125020000e+02, best bound 2.093125020000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0xc9256af6
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# Found heuristic solution: objective 1074.6666667
# Presolve removed 3736 rows and 3648 columns
# Presolve time: 0.01s
# Presolved: 313 rows, 981 columns, 2024 nonzeros
# Variable types: 370 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 2.093125e+02, 196 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     209.3125020  209.31250  0.00%     -    0s
#
# Explored 1 nodes (196 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 209.313 1074.67
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.093125020000e+02, best bound 2.093125020000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4000 rows, 4368 columns and 8356 nonzeros
# Model fingerprint: 0x2ccea9fc
# Variable types: 3840 continuous, 528 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 2e+02]
# Found heuristic solution: objective 1074.6666667
# Presolve removed 3958 rows and 4236 columns
# Presolve time: 0.01s
# Presolved: 42 rows, 132 columns, 272 nonzeros
# Found heuristic solution: objective 303.0347242
# Variable types: 52 continuous, 80 integer (0 binary)
#
# Root relaxation: objective 2.093125e+02, 28 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     209.3125020  209.31250  0.00%     -    0s
#
# Explored 1 nodes (28 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 209.313 303.035 1074.67
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.093125020000e+02, best bound 2.093125020000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4028 rows, 4624 columns and 8712 nonzeros
# Model fingerprint: 0xbf3d4742
# Variable types: 3840 continuous, 784 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 2e+02]
# Found heuristic solution: objective 1074.6666667
# Presolve removed 3941 rows and 4306 columns
# Presolve time: 0.02s
# Presolved: 87 rows, 318 columns, 608 nonzeros
# Found heuristic solution: objective 400.7430566
# Variable types: 103 continuous, 215 integer (0 binary)
#
# Root relaxation: objective 2.093125e+02, 78 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     209.3125020  209.31250  0.00%     -    0s
#
# Explored 1 nodes (78 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 209.313 400.743 1074.67
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.093125020000e+02, best bound 2.093125020000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0x214088fe
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# Found heuristic solution: objective 1074.6666667
# Presolve removed 3744 rows and 3648 columns
# Presolve time: 0.01s
# Presolved: 305 rows, 981 columns, 1895 nonzeros
# Variable types: 370 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 2.093125e+02, 197 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     209.3125020  209.31250  0.00%     -    0s
#
# Explored 1 nodes (197 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 209.313 1074.67
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.093125020000e+02, best bound 2.093125020000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0x657b56d1
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# Found heuristic solution: objective 1074.6666667
# Presolve removed 3744 rows and 3648 columns
# Presolve time: 0.01s
# Presolved: 305 rows, 981 columns, 1895 nonzeros
# Variable types: 370 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 2.093125e+02, 197 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     209.3125020  209.31250  0.00%     -    0s
#
# Explored 1 nodes (197 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 209.313 1074.67
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.093125020000e+02, best bound 2.093125020000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128
# in instance
# in solver
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4049 rows, 4629 columns and 8817 nonzeros
# Model fingerprint: 0x693bbf16
# Variable types: 3840 continuous, 789 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [1e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# Found heuristic solution: objective 1074.6666667
# Presolve removed 3744 rows and 3648 columns
# Presolve time: 0.01s
# Presolved: 305 rows, 981 columns, 1895 nonzeros
# Variable types: 370 continuous, 611 integer (5 binary)
#
# Root relaxation: objective 2.093125e+02, 197 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     209.3125020  209.31250  0.00%     -    0s
#
# Explored 1 nodes (197 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 209.313 1074.67
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.093125020000e+02, best bound 2.093125020000e+02, gap 0.0000%
# dict_keys(['instance', 'model', 'city', 'demand_baseline', 'demand_type', 'outsourcing_cost_multiplier', 'region_multiplier', 'global_multiplier', 'run_time', 'obj_val', 'status', 'gap', 'max_n_shift_start_periods', 'actual_n_shift_start_periods', 'region', 'area', 'theta', 'x__a_theta', 'zminus__a_theta'])
# 128

# %%
#this is an example output of the shift creation code

list_output = []

for filename in os.listdir(r'../shifts'):
    if filename.find('json')>-1:
        with open(f'../shifts/{filename}', 'r') as file:
            data = json.load(file)
            df_ = pd.DataFrame(data)
            list_output.append(df_)

df_output = pd.concat(list_output, ignore_index = True)
df_output.to_excel(r'../run_code/df_shifts_example.xlsx', index = False)

# %%
df_output.head()
# Out:
#                       instance_file   city  demand_baseline demand_type  \
# 0  paris_db=2.00_dt=doublepeak.json  paris              2.0  doublepeak
# 1  paris_db=2.00_dt=doublepeak.json  paris              2.0  doublepeak
# 2  paris_db=2.00_dt=doublepeak.json  paris              2.0  doublepeak
# 3  paris_db=2.00_dt=doublepeak.json  paris              2.0  doublepeak
# 4  paris_db=2.00_dt=doublepeak.json  paris              2.0  doublepeak
#
#    model  max_n_shifts  outsourcing_cost_multiplier  regional_multiplier  \
# 0  fixed           NaN                          1.2                  1.5
# 1  fixed           NaN                          1.2                  1.5
# 2  fixed           NaN                          1.2                  1.5
# 3  fixed           NaN                          1.2                  1.5
# 4   flex           NaN                          1.2                  1.5
#
#    global_multiplier  region              shifts_start  \
# 0                0.8       0          {'0': 0, '1': 4}
# 1                0.8       1          {'0': 0, '1': 4}
# 2                0.8       2          {'0': 0, '1': 4}
# 3                0.8       3          {'0': 0, '1': 4}
# 4                0.8       0  {'0': 0, '1': 2, '2': 4}
#
#                  shifts_end
# 0          {'0': 4, '1': 8}
# 1          {'0': 4, '1': 8}
# 2          {'0': 4, '1': 8}
# 3          {'0': 4, '1': 8}
# 4  {'0': 4, '1': 6, '2': 8}

# %%
df_freq = df_output.copy()
df_freq.drop_duplicates(subset = ['shifts_start'], inplace = True)
df_freq
# Out:
#                              instance_file       city  demand_baseline  \
# 0         paris_db=2.00_dt=doublepeak.json      paris              2.0
# 4         paris_db=2.00_dt=doublepeak.json      paris              2.0
# 704         berlin_db=1.00_dt=uniform.json     berlin              1.0
# 707         berlin_db=1.00_dt=uniform.json     berlin              1.0
# 1204     berlin_db=0.50_dt=doublepeak.json     berlin              0.5
# 1305  frankfurt_db=0.50_dt=doublepeak.json  frankfurt              0.5
# 1344  frankfurt_db=0.50_dt=doublepeak.json  frankfurt              0.5
#
#      demand_type  model  max_n_shifts  outsourcing_cost_multiplier  \
# 0     doublepeak  fixed           NaN                          1.2
# 4     doublepeak   flex           NaN                          1.2
# 704      uniform   flex           NaN                          1.2
# 707      uniform   flex           NaN                          1.2
# 1204  doublepeak   flex           NaN                          1.2
# 1305  doublepeak   flex           NaN                          1.2
# 1344  doublepeak   flex           NaN                          1.8
#
#       regional_multiplier  global_multiplier  region  \
# 0                     1.5                0.8       0
# 4                     1.5                0.8       0
# 704                   1.5                0.8       0
# 707                   1.5                0.8       3
# 1204                  1.5                0.8       0
# 1305                  1.5                0.8       1
# 1344                  1.5                0.8       0
#
#                   shifts_start                shifts_end
# 0             {'0': 0, '1': 4}          {'0': 4, '1': 8}
# 4     {'0': 0, '1': 2, '2': 4}  {'0': 4, '1': 6, '2': 8}
# 704   {'0': 0, '1': 3, '2': 4}  {'0': 4, '1': 7, '2': 8}
# 707   {'0': 0, '1': 1, '2': 4}  {'0': 4, '1': 5, '2': 8}
# 1204                  {'0': 2}                  {'0': 6}
# 1305          {'0': 2, '1': 3}          {'0': 6, '1': 7}
# 1344          {'0': 2, '1': 4}          {'0': 6, '1': 8}
